# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
air_quality = pd.read_csv("air_quality.csv", index_col=0, parse_dates=True)

# %%
air_quality.head()
# Out:
#    Unnamed: 0             datetime  station_antwerp  station_paris  \
# 0         NaN  2019-05-07 02:00:00              NaN            NaN
# 1         NaN  2019-05-07 03:00:00             50.5           25.0
# 2         NaN  2019-05-07 04:00:00             45.0           27.7
# 3         NaN  2019-05-07 05:00:00              NaN           50.4
# 4         NaN  2019-05-07 06:00:00              NaN           61.9
#
#    station_london
# 0            23.0
# 1            19.0
# 2            19.0
# 3            16.0
# 4             NaN

# %%
air_quality.plot()
# Out:
# <AxesSubplot:>

# %%
plt.show()

# %%
air_quality["station_paris"].plot()
# Out:
# <AxesSubplot:>

# %%
air_quality.plot.scatter(x="station_london", y="station_paris", alpha=0.5)
# Out:
# <AxesSubplot:xlabel='station_london', ylabel='station_paris'>

# %%
[
    method_name
    for method_name in dir(air_quality.plot)
    if not method_name.startswith("_")
]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
air_quality.plot.box()
# Out:
# <AxesSubplot:>

# %%
plt.show()

# %%
axs = air_quality.plot.area(figsize=(12, 4), subplots=True)

# %%
plt.show()
